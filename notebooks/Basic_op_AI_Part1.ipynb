# %%
import pandas as pd
import glob
import os
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder

# %%
# List of file paths
file_paths = [
    r"C:\Users\japje\Documents\AI_project\data (2)\data\1_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\233_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\293_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\550_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\619_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\888_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\1281_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\2984_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\3252_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\6000_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\10542_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\10968_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\11232_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\11233_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\12576_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\19028_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\20444_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\20628_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\20710_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\26395_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\36027_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\46782_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\102380_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\116724_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\117419_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\117420_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\117421_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\117422_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\117426_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\155241_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\156862_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\170098_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\171243_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\172008_EBAY-US.csv",
    r"C:\Users\japje\Documents\AI_project\data (2)\data\184488_EBAY-US.csv"
]

# Combine all files into one DataFrame
df = pd.concat([pd.read_csv(file) for file in file_paths], ignore_index=True)

# %%
# Display the first few rows of the combined DataFrame
print(df.head())

# Check the shape (number of rows and columns)
print("Shape of combined data:", df.shape)

# Check for missing values
print("Missing values in each column:\n", df.isnull().sum())

# Get a summary of the DataFrame
print(df.describe())
# Out:
#                                                Title       Item ID  Price  \
# 0  Patiotic Donald Trump 2024 Christmas ornament ...  387496268440   5.90
# 1  🇺🇸 Donald Trump 2024 Christmas Tree Ornament D...  296798492236   5.95
# 2  Legendary 2024 Swarovski Crystal Annual Editio...  395850798435  19.99
# 3  Hallmark Keepsake Barbie Ornaments Variety Mat...  326326677721   7.49
# 4  Christmas Tree Clear Icicle Ornaments Decorati...  305267091978  11.95
#
#   Currency Condition   Category          Seller  Feedback Score  \
# 0      USD       New  Ornaments     santamarket              67
# 1      USD       New  Ornaments   otsportscards            1849
# 2      USD       New  Ornaments        auhonest              74
# 3      USD       New  Ornaments          ob2llc             143
# 4      USD       New  Ornaments  led4everything           99101
#
#    Positive Feedback %  Top Rated Seller  ... Buy It Now Available  \
# ...

# %%
print("Shape of the DataFrame:", df.shape)
# Out:
# Shape of the DataFrame: (96989, 23)

# %%
# Check column data types and basic info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96989 entries, 0 to 96988
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 96989 non-null  object
#  1   Item ID               96989 non-null  int64
#  2   Price                 96989 non-null  float64
#  3   Currency              96989 non-null  object
#  4   Condition             92951 non-null  object
#  5   Category              96989 non-null  object
#  6   Seller                96989 non-null  object
#  7   Feedback Score        96989 non-null  int64
#  8   Positive Feedback %   96989 non-null  float64
#  9   Top Rated Seller      96989 non-null  bool
#  10  Shipping Type         96989 non-null  object
#  11  Shipping Cost         76466 non-null  float64
#  12  Listing Type          96989 non-null  object
#  13  Buy It Now Available  96989 non-null  bool
#  14  Start Time            96989 non-null  object
# ...

# %%
# Check for and remove duplicate rows
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
df.drop_duplicates(inplace=True)
# Out:
# Number of duplicate rows: 20272

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# Verify that duplicates are removed
duplicates_after = df.duplicated().sum()
print(f"Number of duplicate rows after removal: {duplicates_after}")
# Out:
# Number of duplicate rows after removal: 0

# %%
# Convert non-missing values to 1 and missing values to 0 in a ’Gallery URL‘ column
# Convert non-missing values to 1 and missing values to 0 in a ’Large Image URL‘ column
# Convert non-missing values to 1 and missing values to 0 in a ’Super Size Image URL‘ column
df['Store URL_flag'] = df['Store URL'].notna().astype(int)
df['Large Image URL_flag'] = df['Large Image URL'].notna().astype(int)
df['Super Size Image URL_flag'] = df['Super Size Image URL'].notna().astype(int)

# %%
#One-Hot Encoding for Listing Type (manually)
listing_type_categories = df['Listing Type'].unique()
for category in listing_type_categories:
    df[f'Listing Type_{category}'] = (df['Listing Type'] == category).astype(int)

#One-Hot Encoding for Shipping Type (manually)
shipping_type_categories = df['Shipping Type'].unique()
for category in shipping_type_categories:
    df[f'Shipping Type_{category}'] = (df['Shipping Type'] == category).astype(int)

#Label Encoding for Top Rated Seller (binary column: True/False)
label_encoder = LabelEncoder()
df['Top Rated Seller'] = label_encoder.fit_transform(df['Top Rated Seller'])

#One-Hot Encoding for Condition (manually)
condition_categories = df['Condition'].unique()
for category in condition_categories:
    df[f'Condition_{category}'] = (df['Condition'] == category).astype(int)

#Ensure that the currency column is set to USD for all rows
df['Currency'] = 'USD'

#Drop original categorical columns as we have encoded them
df.drop(columns=['Listing Type', 'Shipping Type', 'Condition'], inplace=True)

#Show the transformed DataFrame
print(df)
# Out:
#                                                    Title       Item ID  Price  \
# 0      Patiotic Donald Trump 2024 Christmas ornament ...  387496268440   5.90
# 1      🇺🇸 Donald Trump 2024 Christmas Tree Ornament D...  296798492236   5.95
# 2      Legendary 2024 Swarovski Crystal Annual Editio...  395850798435  19.99
# 3      Hallmark Keepsake Barbie Ornaments Variety Mat...  326326677721   7.49
# 4      Christmas Tree Clear Icicle Ornaments Decorati...  305267091978  11.95
# ...                                                  ...           ...    ...
# 96984      Tags with Hot Stamping Xmas Tags for Presents  286145966181  11.00
# 96985  100Pieces Christmas Tags Rope Gold Craft Paper...  186729552656  10.79
# 96986  96 Sets Valentine Day Paper Tags Holiday Hangi...  305803725742  13.07
# 96987  96 Sets Valentine Day Paper Tags Holiday Hangi...  235776926729  12.07
# 96988  96 Sets Valentine Day Paper Tags Holiday Hangi...  235726746752   8.14
#
# ...

# %%
# List of numerical columns to scale
numerical_columns = ['Price', 'Feedback Score']

# Define the ColumnTransformer
column_transformer = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_columns)  # Scaling for numerical columns
    ],
    remainder='passthrough'  # Keep untransformed columns unchanged
)

# Apply transformation
final = column_transformer.fit_transform(df)

# Get column names, including original ones for 'passthrough' columns
column_names = column_transformer.get_feature_names_out()

# Convert the result back to a DataFrame with proper column names
df_cleaned = pd.DataFrame(final, columns=column_names)

# Show the transformed DataFrame
print(df_cleaned.head())
# Out:
#   num__Price num__Feedback Score  \
# 0  -0.218208           -0.295472
# 1  -0.217724           -0.293413
# 2   -0.08175           -0.295464
# 3  -0.202809           -0.295384
# 4  -0.159615           -0.181028
#
#                                     remainder__Title remainder__Item ID  \
# 0  Patiotic Donald Trump 2024 Christmas ornament ...       387496268440
# 1  🇺🇸 Donald Trump 2024 Christmas Tree Ornament D...       296798492236
# 2  Legendary 2024 Swarovski Crystal Annual Editio...       395850798435
# 3  Hallmark Keepsake Barbie Ornaments Variety Mat...       326326677721
# 4  Christmas Tree Clear Icicle Ornaments Decorati...       305267091978
#
#   remainder__Currency remainder__Category remainder__Seller  \
# 0                 USD           Ornaments       santamarket
# 1                 USD           Ornaments     otsportscards
# 2                 USD           Ornaments          auhonest
# 3                 USD           Ornaments            ob2llc
# ...
